# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException, WebDriverException
from serde import serialize, deserialize
from serde.json import to_json, from_json
from dataclasses import dataclass
from time import sleep

# %%
def accept_cookies(driver: webdriver.chrome.webdriver.WebDriver): 
    """Accept cookies on Spoticar pages."""
    button = WebDriverWait(driver, 30).until(
        EC.presence_of_element_located((
            By.ID,
            "_psaihm_id_accept_all_btn"
        ))
    )
    button.click()

# %%
@serialize
@deserialize
@dataclass
class Voiture:
    modele: str
    carburant: str
    prix: int
    kilometrage: int
    garantie_kilometrage: str
    boite_de_vitesse: str
    transmission: int
    couleur: str
    garantie: str
    date_mise_circulation: int
    puissance: int
    silhouette: str
    nb_places: int
    utilisation_prec: str
    puissance_fiscale: int
    critair: int
    ptac: int
    nb_portes: int

# %%
def formalisation(modele, carburant, prix, kilometrage, garantie_kilometrage, boite_de_vitesse, transmission, couleur,
        garantie, date_mise_circulation, puissance, silhouette, nb_places, utilisation_prec,
        puissance_fiscale, critair, ptac, nb_portes):
    if modele == "NA":
        modele = modele
    else:        
        modele = modele[8:]
    
    carburant = carburant
    
    if kilometrage == "NA":
        kilometrage = kilometrage
    else:
        try :
            kilometrage = int(str(kilometrage[:-3]).replace(' ',""))
        except:
            kilometrage = kilometrage

    if prix == "NA":
        prix = prix
    else:
        prix = int(str(prix[:-2].replace(' ','')))
    
    if garantie_kilometrage == "NA":
        garantie_kilometrage = garantie_kilometrage
    else:
        garantie_kilometrage = garantie_kilometrage
    
    if boite_de_vitesse == "NA":
        boite_de_vitesse = boite_de_vitesse
    else:
        boite_de_vitesse = boite_de_vitesse
    
    if transmission =="NA":
        pass
    else:
        transmission = int(transmission[0])
    
    if couleur == "NA":
        couleur = couleur
    else:
        couleur = couleur
    
    if garantie == "NA":
        garantie = garantie
    else:
        garantie = garantie
    
    if date_mise_circulation == "NA":
        date_mise_circulation = date_mise_circulation
    else:
        date_mise_circulation = int(date_mise_circulation[3:])
    
    if puissance == "NA":
        puissance =puissance
    else:
        puissance = int(str(puissance[:-3]).replace(' ',""))
    
    if silhouette == "NA":
        silhouette = silhouette
    else:
        silhouette = silhouette
    
    if nb_places == "NA":
        nb_places = nb_places
    else:
        nb_places = int(nb_places[0])
    
    if puissance_fiscale == "NA":
        puissance_fiscale = puissance_fiscale
    else:
        puissance_fiscale = int(str(puissance_fiscale[:-3]).replace(' ',""))
    
    if critair == "NA":
        critair = critair
    else:
        critair = int(critair[7:])

    if ptac == "NA":
        ptac = ptac
    else:
        ptac = int(str(ptac[:-3]))

    if nb_portes == "NA":
        nb_portes = nb_portes
    else:
        nb_portes = int(nb_portes)
    
    if utilisation_prec =="NA":
        utilisation_prec = utilisation_prec
    else:
        utilisation_prec = utilisation_prec
    

    return (modele, carburant, prix, kilometrage, garantie_kilometrage, boite_de_vitesse, transmission, couleur,
        garantie, date_mise_circulation, puissance, silhouette, nb_places, utilisation_prec,
        puissance_fiscale, critair, ptac, nb_portes)

# %%
def recolt_data(driver):
    car_list = list()
    for i in range(1,601):
        if i % 12 == 0:
            driver.find_element(By.CSS_SELECTOR, '#see-more-results > .tags-and-alerts-button-text').click()
            sleep(3)
        sleep(1)
        site = f'.reskin-product-card:nth-child({i}) .title'
        driver.find_element(By.CSS_SELECTOR, site).click()
        sleep(2)
        home_page = driver.window_handles[0]
        window_after = driver.window_handles[1]
        driver.switch_to.window(window_after)
        try:
            modele = driver.find_element(By.CSS_SELECTOR, '.product-line').text
        except NoSuchElementException:
            modele = "NA"

        try:
            carburant = driver.find_element(By.CSS_SELECTOR,'.field_vo_fuel > .title-data').text
        except NoSuchElementException:
            carburant ="NA"

        try:    
            prix = driver.find_element(By.CSS_SELECTOR, '.price-taxe-div > span').text
        except NoSuchElementException:
            prix = "NA"

        try:
            kilometrage = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-km > .title-data').text
        except NoSuchElementException:
            kilometrage = "NA"

        try:
            garantie_kilometrage = driver.find_element(By.CSS_SELECTOR, '.garantie-tooltip > .title-data').text
        except NoSuchElementException:
            garantie = "NA"

        try:
            boite_de_vitesse = driver.find_element(By.CSS_SELECTOR, '.field_vo_gear_box > .title-data').text
        except NoSuchElementException:
            boite_de_vitesse = "NA"

        try :
            transmission = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-transmission > .title-data').text
        except NoSuchElementException:
                transmission = "NA"

        try:
            couleur = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-color > .title-data').text
        except NoSuchElementException:
            couleur = "NA"

        try:    
            garantie = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-warranty > .title-data').text
        except NoSuchElementException:
            garantie = "NA"

        try:
            date_mise_circulation = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-entry-into-service > .title-data').text
        except NoSuchElementException:
            date_mise_circulation = "NA"

        try:
            puissance = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-din-power > .title-data').text
        except NoSuchElementException:
            puissance = "NA"

        try:    
            silhouette = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-silhouette > .title-data').text
        except NoSuchElementException:
            silhouette = "NA"

        try:
            nb_places = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-nbPlaces > .title-data').text
        except NoSuchElementException:
            nb_places = "NA"
            
        try:
            utilisation_prec = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-origin > .title-data').text
        except NoSuchElementException:
            utilisation_prec = "NA"

        try:
            puissance_fiscale = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-fiscal-power > .title-data').text
        except NoSuchElementException:
            puissance_fiscale = "NA"

        try:    
            critair = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-green-zone > .title-data').text
        except NoSuchElementException:
            critair = "NA"

        try:
            ptac = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-ptac > .title-data').text
        except NoSuchElementException:
            ptac = "NA"

        try:
            nb_portes = driver.find_element(By.CSS_SELECTOR, '.psa-fiche-vo-characteristics-list-nb-portes > .title-data').text
        except NoSuchElementException:
            nb_portes = "NA"
            
        (modele, carburant, prix, kilometrage, garantie_kilometrage, boite_de_vitesse, transmission, couleur,
        garantie, date_mise_circulation, puissance, silhouette, nb_places, utilisation_prec,
        puissance_fiscale, critair, ptac, nb_portes) = formalisation(modele, carburant, prix, kilometrage, garantie_kilometrage, boite_de_vitesse, transmission, couleur,
        garantie, date_mise_circulation, puissance, silhouette, nb_places, utilisation_prec,
        puissance_fiscale, critair, ptac, nb_portes)

        car = Voiture(modele, carburant, prix, kilometrage, garantie_kilometrage, boite_de_vitesse, transmission, couleur,
        garantie, date_mise_circulation, puissance, silhouette, nb_places, utilisation_prec,
        puissance_fiscale, critair, ptac, nb_portes)
        car_list.append(car)    
        try:
            driver.find_element(By.CSS_SELECTOR, '.a.ng-binding').click()
        except NoSuchElementException:
            pass
        driver.switch_to.window(window_after)
        try :
            driver.execute_script("window.close('');")
        except WebDriverException :
            pass
        driver.switch_to.window(home_page)
        sleep(0.5)
    driver.quit()
    return car_list

# %%
def acces_site(URL):
    driver = webdriver.Chrome()
    driver.maximize_window()
    driver.get(URL)
    sleep(2)
    accept_cookies(driver)
    sleep(3)
    driver.find_element(By.ID, 'search-input-filter-home').click()
    sleep(2)
    driver.find_element(By.ID, 'search-input-filter-home').send_keys("Peugeot" + Keys.ENTER)
    sleep(5)
    driver.find_element(By.ID, 'count').click()
    sleep(5)
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    resultat = recolt_data(driver)
    return(resultat)

# %%
donnees2 = acces_site('https://www.spoticar.fr/')

# %%
donnees2
# Out:
# [Voiture(modele='308', carburant='Diesel', prix=20290, kilometrage=75967, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Blanc', garantie='SPOTICAR PREMIUM', date_mise_circulation=2019, puissance=130, silhouette='Berline', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=6, critair=2, ptac=1890, nb_portes=5),
#  Voiture(modele='3008', carburant='Diesel', prix=31900, kilometrage=29066, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission='NA', couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=130, silhouette='SUV-4x4', nb_places=5, utilisation_prec='NA', puissance_fiscale=7, critair=2, ptac='NA', nb_portes=5),
#  Voiture(modele='3008', carburant='Essence', prix=33920, kilometrage=31997, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission='NA', couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=130, silhouette='SUV-4x4', nb_places=5, utilisation_prec='NA', puissance_fiscale=7, critair=1, ptac='NA', nb_portes=5),
#  Voiture(modele='2008', carburant='Essence', prix=21980, kilometrage=40952, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission='NA', couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=100, silhouette='SUV-4x4', nb_places=5, utilisation_prec='NA', puissance_fiscale=5, critair=1, ptac='NA', nb_portes=5),
#  Voiture(modele='2008', carburant='Essence', prix=22990, kilometrage=7901, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission='NA', couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=100, silhouette='SUV-4x4', nb_places=5, utilisation_prec='Ex-Particulier', puissance_fiscale=5, critair=1, ptac='NA', nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=21990, kilometrage=19050, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission='NA', couleur='Noir', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=100, silhouette='Citadine', nb_places=5, utilisation_prec='NA', puissance_fiscale=5, critair=1, ptac='NA', nb_portes=5),
#  Voiture(modele='3008', carburant='Diesel', prix=34390, kilometrage=24889, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Blanc', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=131, silhouette='SUV-4x4', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=7, critair=2, ptac=2000, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=17890, kilometrage=19422, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Blanc', garantie='SPOTICAR PREMIUM', date_mise_circulation=2020, puissance=102, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=5, critair=1, ptac=1595, nb_portes=5),
#  Voiture(modele='3008', carburant='Diesel', prix=32990, kilometrage=38139, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Bleu', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=131, silhouette='SUV-4x4', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=7, critair=2, ptac=2000, nb_portes=5),
#  Voiture(modele='308', carburant='Essence', prix=20490, kilometrage=50816, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2019, puissance=130, silhouette='Berline', nb_places=5, utilisation_prec='Ex-Import', puissance_fiscale=6, critair=1, ptac=1750, nb_portes=5),
#  Voiture(modele='2008', carburant='Essence', prix=18990, kilometrage=45494, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2019, puissance=110, silhouette='SUV-4x4', nb_places=5, utilisation_prec='Ex-Import', puissance_fiscale=6, critair=1, ptac=1680, nb_portes=5),
#  Voiture(modele='108', carburant='Essence', prix=11990, kilometrage=15101, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Rouge', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=72, silhouette='Citadine', nb_places='NA', utilisation_prec='Ex-Particulier', puissance_fiscale=4, critair=1, ptac=1240, nb_portes=5),
#  Voiture(modele='2008', carburant='Essence', prix
silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Société', puissance_fiscale=4, critair=1, ptac=1515, nb_portes=5),
#  Voiture(modele='3008', carburant='Diesel', prix=38490, kilometrage=4290, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Bleu', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=131, silhouette='SUV-4x4', nb_places=5, utilisation_prec='NA', puissance_fiscale=7, critair=2, ptac=2000, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=12490, kilometrage=30057, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Blanc', garantie='SPOTICAR PREMIUM', date_mise_circulation=2019, puissance=68, silhouette='Citadine', nb_places=5, utilisation_prec='NA', puissance_fiscale=4, critair=1, ptac=1515, nb_portes=5),
#  Voiture(modele='308', carburant='Essence', prix=24990, kilometrage=23222, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Vert', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=110, silhouette='Berline', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=6, critair=1, ptac=1770, nb_portes=5),
#  Voiture(modele='3008', carburant='Diesel', prix=32990, kilometrage=16378, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Blanc', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=131, silhouette='SUV-4x4', nb_places=5, utilisation_prec='Ex-Import', puissance_fiscale=7, critair=2, ptac=1980, nb_portes=5),
#  Voiture(modele='308', carburant='Hybride rechargeable', prix=37990, kilometrage=4861, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Rouge', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=150, silhouette='Berline', nb_places=5, utilisation_prec='Ex-Particulier', puissance_fiscale=8, critair=1, ptac=2120, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=22990, kilometrage=37994, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Jaune', garantie='SPOTICAR PREMIUM', date_mise_circulation=2020, puissance=102, silhouette='Citadine', nb_places=5, utilisation_prec='NA', puissance_fiscale=5, critair=1, ptac=1595, nb_portes=5),
#  Voiture(modele='208', carburant='Electrique', prix=26490, kilometrage=16606, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Bleu', garantie='SPOTICAR PREMIUM', date_mise_circulation=2020, puissance='NA', silhouette='Citadine', nb_places=5, utilisation_prec='NA', puissance_fiscale=4, critair=0, ptac='NA', nb_portes=5),
#  Voiture(modele='5008', carburant='Diesel', prix=31490, kilometrage=57430, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2019, puissance=130, silhouette='SUV-4x4', nb_places=7, utilisation_prec='Ex-Particulier', puissance_fiscale=6, critair=2, ptac=2200, nb_portes=5),
#  Voiture(modele='208', carburant='Electrique', prix=25990, kilometrage=41203, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Blanc', garantie='SPOTICAR PREMIUM', date_mise_circulation=2020, puissance='NA', silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Société', puissance_fiscale=4, critair=0, ptac='NA', nb_portes=5),
#  Voiture(modele='208', carburant='Electrique', prix=26990, kilometrage=11519, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Bleu', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=136, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=4, critair=0, ptac=1910, nb_portes=5),
#  Voiture(modele='BOXER', carburant='Diesel', prix=24490, kilometrage=110315, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2018, puissance=163, silhouette='Utilitaire', nb_places=3, utilisation_prec='Ex-Société', puissance_fiscale=7, critair=2, ptac=3500, nb_portes=4),
#  Voiture(modele='2008', carburant='Essence', prix=22990, kilometrage=31481, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Orange', garantie='SPOTICAR PREMIUM', date_mise_circulation=2020, puissance=102, silhouette='SUV-4x4', nb_places=5, utilisation_prec='NA', puissance_fiscale=5, critair=1, ptac=1715, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=17990, kilometrage=16777, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=75, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=4, critair=1, ptac=1510, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=17990, kilometrage=17220, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Rouge', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=75, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=4, critair=1, ptac=1510, nb_portes=5),
#  Voiture(modele='208', carburant='Electrique', prix=26990, kilometrage=8260, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Noir', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=136, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=4, critair=0, ptac=1910, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=18490, kilometrage=18320, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=75, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=4, critair=1, ptac=1510, nb_portes=5),
#  Voiture(modele='EXPERT', carburant='Diesel', prix=35490, kilometrage=10, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Noir', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=145, silhouette='Utilitaire', nb_places=3, utilisation_prec='NA', puissance_fiscale=7, critair=2, ptac=2830, nb_portes='NA'),
#  Voiture(modele='208', carburant='Essence', prix=24990, kilometrage=15700, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2020, puissance=102, silhouette='Citadine', nb_places=5, utilisation_prec='NA', puissance_fiscale=5, critair=1, ptac=1625, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=12290, kilometrage=37905, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Blanc', garantie='SPOTICAR PREMIUM', date_mise_circulation=2019, puissance=68, silhouette='Citadine', nb_places=5, utilisation_prec='NA', puissance_fiscale=4, critair=1, ptac=1515, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=22490, kilometrage=21482, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Bleu', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=102, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Particulier', puissance_fiscale=5, critair=1, ptac=1595, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=21490, kilometrage=39695, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=102, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=5, critair=1, ptac=1595, nb_portes=5),
#  Voiture(modele='2008', carburant='Diesel', prix=28990, kilometrage=48476, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Noir', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=131, silhouette='SUV-4x4', nb_places=5, utilisation_prec='Ex-Particulier', puissance_fiscale=7, critair=2, ptac=1770, nb_portes=5),
#  Voiture(modele='208', carburant='Diesel', prix=16490, kilometrage=66543, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Rouge', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=102, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Auto-école', puissance_fiscale=5, critair=2, ptac=1645, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=12490, kilometrage=40733, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Blanc', garantie='SPOTICAR PREMIUM', date_mise_circulation=2018, puissance=68, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Société', puissance_fiscale=4, critair=1, ptac=1515, nb_portes=5),
#  Voiture(modele='2008', carburant='Essence', prix=33990, kilometrage=20790, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Blanc', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=131, silhouette='SUV-4x4', nb_places=5, utilisation_prec='NA', puissance_fiscale=7, critair=1, ptac=1752, nb_portes=5),
#  Voiture(modele='5008', carburant='Diesel', prix=37490, kilometrage=5505, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=131, silhouette='SUV-4x4', nb_places=7, utilisation_prec='Ex-Import', puissance_fiscale=7, critair=2, ptac=2200, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=17990, kilometrage=17370, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Blanc', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=75, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=4, critair=1, ptac=1510, nb_portes=5),
#  Voiture(modele='3008', carburant='Diesel', prix=34990, kilometrage=16459, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=131, silhouette='SUV-4x4', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=7, critair=2, ptac=2000, nb_portes=5),
#  Voiture(modele='208', carburant='Electrique', prix=27490, kilometrage=7310, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=136, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=4, critair=0, ptac=1910, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=12490, kilometrage=45284, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Blanc', garantie='SPOTICAR PREMIUM', date_mise_circulation=2018, puissance=68, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Société', puissance_fiscale=4, critair=1, ptac=1515, nb_portes=5),
#  Voiture(modele='2008', carburant='Essence', prix=22990, kilometrage=15500, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=102, silhouette='SUV-4x4', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=5, critair=1, ptac=1715, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=17990, kilometrage=16302, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Jaune', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=75, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=4, critair=1, ptac=1510, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=22990, kilometrage=33445, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Rouge', garantie='SPOTICAR PREMIUM', date_mise_circulation=2020, puissance=102, silhouette='Citadine', nb_places=5, utilisation_prec='NA', puissance_fiscale=5, critair=1, ptac=1595, nb_portes=5),
#  Voiture(modele='208', carburant='Essence', prix=17790, kilometrage=14000, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=75, silhouette='Citadine', nb_places=5, utilisation_prec='Ex-Loueur', puissance_fiscale=4, critair=1, ptac=1510, nb_portes=5),
#  Voiture(modele='2008', carburant='Electrique', prix=32990, kilometrage=9007, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2021, puissance=136, silhouette='SUV-4x4', nb_places=5, utilisation_prec='NA', puissance_fiscale=4, critair=0, ptac=2030, nb_portes=5),
#  Voiture(modele='308', carburant='Diesel', prix=33990, kilometrage=3254, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Noir', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=131, silhouette='Berline', nb_places=5, utilisation_prec='NA', puissance_fiscale=7, critair=2, ptac=1940, nb_portes=5),
#  Voiture(modele='2008', carburant='Diesel', prix=31490, kilometrage=2535, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=131, silhouette='SUV-4x4', nb_places=5, utilisation_prec='Ex-Import', puissance_fiscale=7, critair=2, ptac=1770, nb_portes=5),
#  Voiture(modele='3008', carburant='Diesel', prix=37490, kilometrage=21164, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Noir', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=131, silhouette='SUV-4x4', nb_places=5, utilisation_prec='NA', puissance_fiscale=7, critair=2, ptac=2000, nb_portes=5),
#  Voiture(modele='EXPERT', carburant='Diesel', prix=36490, kilometrage=10, garantie_kilometrage='non garanti', boite_de_vitesse='Manuelle', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=145, silhouette='Utilitaire', nb_places=3, utilisation_prec='NA', puissance_fiscale=7, critair=2, ptac='NA', nb_portes='NA'),
#  Voiture(modele='EXPERT', carburant='Diesel', prix=38990, kilometrage=10, garantie_kilometrage='non garanti', boite_de_vitesse='Automatique', transmission=2, couleur='Gris', garantie='SPOTICAR PREMIUM', date_mise_circulation=2022, puissance=177, silhouette='Utilitaire', nb_places=6, utilisation_prec='NA', puissance_fiscale=7, critair=2, ptac=2790, nb_portes='NA')]

# %%
f = open("donnees.json", "w")
f.write(to_json(donnees2))
# Out:
# 228034

# %%
""" if i % 100 == 0:
            url = driver.current_url
            driver.get(url)
            sleep(2)
            for j in range(0, (i//12)+1):
                driver.find_element(By.CSS_SELECTOR, '#see-more-results > .tags-and-alerts-button-text').click()
                sleep(8) """
# Out:
# " if i % 100 == 0:\n            url = driver.current_url\n            driver.get(url)\n            sleep(2)\n            for j in range(0, (i//12)+1):\n                driver.find_element(By.CSS_SELECTOR, '#see-more-results > .tags-and-alerts-button-text').click()\n                sleep(8) "
